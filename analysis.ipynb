# %% [markdown]
# # Crosscoder Analysis and Exploration

# %%
import torch
import seaborn as sns
from nnsight import TransformersModel

# %%
from transformers import AutoTokenizer

# %%
model_id = "meta-llama/Meta-Llama-3.1-8B-Instruct"

model = TransformersModel(model_id, device_map='auto', torch_dtype=torch.float16, trust_remote_code=True)
